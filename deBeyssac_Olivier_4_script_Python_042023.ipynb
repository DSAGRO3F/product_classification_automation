# %%
import pandas as pd
import requests
import json
import csv
import os

# %% [markdown]
# # Construction et obtention des informations par la requete http.

# %%
# url = "https://edamam-food-and-grocery-database.p.rapidapi.com/auto-complete"

# querystring = {"q":"Champagne","limit":"10"}

# headers = {
# 	"X-RapidAPI-Key": "2a57a56e6bmsh7d4fed488c48c7ap175bcejsn6baabdc408cd",
# 	"X-RapidAPI-Host": "edamam-food-and-grocery-database.p.rapidapi.com"
# }

# response = requests.get(url, headers=headers, params=querystring)

# output = response.json()
# print(type(output))
# print("Liste des 10 premiers produits à base de champagne: {}".format(output))

# %%
url = "https://edamam-food-and-grocery-database.p.rapidapi.com/api/food-database/v2/parser"

#querystring = {"ingr":"champagne","category[0]":"generic-foods", "limit": 10}

querystring = {
  "ingr": "champagne",
  "parsed":[{"food": {"foodId": "",
                      "label": "",
                      "category": "",
                      "foodContentsLabel": "",
                      "image": ""}}]}

headers = {
	"X-RapidAPI-Key": "2a57a56e6bmsh7d4fed488c48c7ap175bcejsn6baabdc408cd",
	"X-RapidAPI-Host": "edamam-food-and-grocery-database.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

output = response.json()

print(type(output))
print(output)
# Out:
# <class 'dict'>
# ...

# %%
for key, value in output.items():
  print(key)
  print(value)
# Out:
# text
# champagne
# parsed
# [{'food': {'foodId': 'food_a656mk2a5dmqb2adiamu6beihduu', 'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_table_white_wine', 'label': 'Champagne', 'knownAs': 'dry white wine', 'nutrients': {'ENERC_KCAL': 82.0, 'PROCNT': 0.07, 'FAT': 0.0, 'CHOCDF': 2.6, 'FIBTG': 0.0}, 'category': 'Generic foods', 'categoryLabel': 'food', 'image': 'https://www.edamam.com/food-img/a71/a718cf3c52add522128929f1f324d2ab.jpg'}}]
# hints
# ...

# %%
output['parsed']
# Out:
# [{'food': {'foodId': 'food_a656mk2a5dmqb2adiamu6beihduu',
#    'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_table_white_wine',
#    'label': 'Champagne',
#    'knownAs': 'dry white wine',
#    'nutrients': {'ENERC_KCAL': 82.0,
#     'PROCNT': 0.07,
#     'FAT': 0.0,
#     'CHOCDF': 2.6,
#     'FIBTG': 0.0},
#    'category': 'Generic foods',
#    'categoryLabel': 'food',
#    'image': 'https://www.edamam.com/food-img/a71/a718cf3c52add522128929f1f324d2ab.jpg'}}]

# %%
output['_links']
# Out:
# {'next': {'title': 'Next page',
#   'href': 'https://api.edamam.com/api/food-database/v2/parser?session=40&app_key=69d004c3e3c5b967261e625baea627fc&parsed=food&app_id=85b409cf&ingr=champagne'}}

# %%
list_1 = output['hints']

# %%
output['hints'][0]
# Out:
# {'food': {'foodId': 'food_a656mk2a5dmqb2adiamu6beihduu',
#   'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_table_white_wine',
#   'label': 'Champagne',
#   'knownAs': 'dry white wine',
#   'nutrients': {'ENERC_KCAL': 82.0,
#    'PROCNT': 0.07,
#    'FAT': 0.0,
#    'CHOCDF': 2.6,
#    'FIBTG': 0.0},
#   'category': 'Generic foods',
#   'categoryLabel': 'food',
#   'image': 'https://www.edamam.com/food-img/a71/a718cf3c52add522128929f1f324d2ab.jpg'},
#  'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#    'label': 'Whole',
#    'weight': 750.0},
#   {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#    'label': 'Serving',
#    'weight': 147.0},
#   {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_splash',
#    'label': 'Splash',
#    'weight': 84.0},
#   {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#    'label': 'Gram',
#    'weight': 1.0},
# ...

# %%
print(type(list_1))
print(len(list_1))
list_1
# Out:
# <class 'list'>
# 20
# [{'food': {'foodId': 'food_a656mk2a5dmqb2adiamu6beihduu',
#    'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_table_white_wine',
#    'label': 'Champagne',
#    'knownAs': 'dry white wine',
#    'nutrients': {'ENERC_KCAL': 82.0,
#     'PROCNT': 0.07,
#     'FAT': 0.0,
#     'CHOCDF': 2.6,
#     'FIBTG': 0.0},
#    'category': 'Generic foods',
#    'categoryLabel': 'food',
#    'image': 'https://www.edamam.com/food-img/a71/a718cf3c52add522128929f1f324d2ab.jpg'},
#   'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#     'label': 'Whole',
#     'weight': 750.0},
#    {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#     'label': 'Serving',
#     'weight': 147.0},
#    {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_splash',
#     'label': 'Splash',
#     'weight': 84.0},
#    {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#     'label': 'Gram',
#     'weight': 1.0},
# ...

# %%
list_1[0]
# Out:
# {'food': {'foodId': 'food_a656mk2a5dmqb2adiamu6beihduu',
#   'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_table_white_wine',
#   'label': 'Champagne',
#   'knownAs': 'dry white wine',
#   'nutrients': {'ENERC_KCAL': 82.0,
#    'PROCNT': 0.07,
#    'FAT': 0.0,
#    'CHOCDF': 2.6,
#    'FIBTG': 0.0},
#   'category': 'Generic foods',
#   'categoryLabel': 'food',
#   'image': 'https://www.edamam.com/food-img/a71/a718cf3c52add522128929f1f324d2ab.jpg'},
#  'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#    'label': 'Whole',
#    'weight': 750.0},
#   {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#    'label': 'Serving',
#    'weight': 147.0},
#   {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_splash',
#    'label': 'Splash',
#    'weight': 84.0},
#   {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#    'label': 'Gram',
#    'weight': 1.0},
# ...

# %%
list_1[0]['food']['image']
# Out:
# 'https://www.edamam.com/food-img/a71/a718cf3c52add522128929f1f324d2ab.jpg'

# %%
list_1[1]['food']['image']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-5d4d45bd35ee> in <cell line: 1>()
# ----> 1 list_1[1]['food']['image']
#
# KeyError: 'image'

# %%
l_food_Id = []
l_label = []
l_category = []
l_foodcontentslabel = []
l_image = []



def get_info(searched_label_1, searched_label_2, searched_label_3, searched_label_4, searched_label_5):
  for dico in list_1:
    #print("dico: {}".format(dico))

    if searched_label_1 in dico['food']:
      value = dico['food'][searched_label_1]
      l_food_Id.append(value)

    else:
      l_food_Id.append('no_value')

    if searched_label_2 in dico['food']:
      value = dico['food'][searched_label_2]
      l_label.append(value)

    else:
      l_label.append('no_value')


    if searched_label_3 in dico['food']:
      value = dico['food'][searched_label_3]
      l_category.append(value)

    else:
      l_category.append('no_value')


    if searched_label_4 in dico['food']:
      value = dico['food'][searched_label_4]
      l_foodcontentslabel.append(value)

    else:
      l_foodcontentslabel.append('no_value')


    if searched_label_5 in dico['food']:
      value = dico['food'][searched_label_5]
      l_image.append(value)

    else:
      l_image.append('no_value')

  print(l_image)


  d_glob = {'foodId': l_food_Id, 'label': l_label, 'category': l_category,
            'foodContentsLabel': l_foodcontentslabel, 'image': l_image}

  df_glob = pd.DataFrame(d_glob)

  df_glob = df_glob.head(10)

  return df_glob

# %%
df_glob = get_info('foodId', 'label', 'category', 'foodContentsLabel', 'image')
# Out:
# ['https://www.edamam.com/food-img/a71/a718cf3c52add522128929f1f324d2ab.jpg', 'no_value', 'https://www.edamam.com/food-img/d88/d88b64d97349ed062368972113124e35.jpg', 'no_value', 'no_value', 'https://www.edamam.com/food-img/ab2/ab2459fc2a98cd35f68b848be2337ecb.jpg', 'no_value', 'no_value', 'no_value', 'no_value', 'no_value', 'no_value', 'no_value', 'no_value', 'no_value', 'no_value', 'https://www.edamam.com/food-img/736/736a3e27a63d799d4073d2774075b509.png', 'no_value', 'no_value', 'no_value']

# %% [markdown]
# # Création nouveau directory.

# %%
print("Creating new folder...")
outputs_dir = '/content/drive/MyDrive/Colab Notebooks/P_6/outputs_dir'
if not os.path.exists(outputs_dir):
    os.makedirs(outputs_dir)


if os.path.isdir(outputs_dir):
  print("New folder created")
# Out:
# Creating new folder...
# New folder created

# %% [markdown]
# # Création folder dans le directory.

# %%
print("Création emplacement fichier...")
csv_path_folder =  '/content/drive/MyDrive/Colab Notebooks/P_6/outputs_dir/csv_output'

if not os.path.exists(csv_path_folder):
  os.makedirs(csv_path_folder)

if os.path.isdir(csv_path_folder):
  print("New csv folder created")
# Out:
# Création emplacement fichier...
# New csv folder created

# %% [markdown]
# # Sauver le dataframe en format csv.

# %%
file_name = 'csv_req_output'

df_glob.to_csv(csv_path_folder + '/' + file_name, index=False)

# %% [markdown]
# # Lire le fichier csv.

# %%
df_req_output = pd.read_csv(csv_path_folder + '/' + file_name, sep=',')

# %%
df_req_output
# Out:
#                               foodId                             label  \
# 0  food_a656mk2a5dmqb2adiamu6beihduu                         Champagne
# 1  food_b753ithamdb8psbt0w2k9aquo06c  Champagne Vinaigrette, Champagne
# 2  food_b3dyababjo54xobm6r8jzbghjgqe  Champagne Vinaigrette, Champagne
# 3  food_a9e0ghsamvoc45bwa2ybsa3gken9  Champagne Vinaigrette, Champagne
# 4  food_an4jjueaucpus2a3u1ni8auhe7q9  Champagne Vinaigrette, Champagne
# 5  food_bmu5dmkazwuvpaa5prh1daa8jxs0     Champagne Dressing, Champagne
# 6  food_alpl44taoyv11ra0lic1qa8xculi             Champagne Buttercream
# 7  food_byap67hab6evc3a0f9w1oag3s0qf                  Champagne Sorbet
# 8  food_am5egz6aq3fpjlaf8xpkdbc2asis                Champagne Truffles
# 9  food_bcz8rhiajk1fuva0vkfmeakbouc0             Champagne Vinaigrette
#
#          category                                  foodContentsLabel  \
# 0   Generic foods                                           no_value
# ...
